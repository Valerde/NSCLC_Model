# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("input/data_.xlsx",index_col=0)

# %%
data_ = data.copy()
data_
# Out:
#          Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# ID
# 1275807                4                        2                         4
# 1193683                1                        1                         2
# 1170419               10                       10                        10
# 1190386                4                        6                         6
# 1202125                4                        1                         1
# ...                  ...                      ...                       ...
# 493452                 1                        1                         3
# 1116132                6                        3                         4
# 1133136                3                        1                         1
# 1158247                1                        1                         1
# 1206314                1                        2                         3
#
# ...

# %%
data_ = data_.iloc[:,:10]

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data_, alpha=1, figsize=(18,18))
plt.show()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(data_,class_column='Class',color=['k','r'])
plt.show()

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(data_,class_column='Class', color=['k','r'])
plt.show()

# %%
from pandas.plotting import radviz

# %%
radviz(data_,class_column='Class', color=['k','r'])
plt.show()
# Out:
# /root/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/misc.py:178: RuntimeWarning: invalid value encountered in divide
#   y = (s * row_).sum(axis=0) / row.sum()
